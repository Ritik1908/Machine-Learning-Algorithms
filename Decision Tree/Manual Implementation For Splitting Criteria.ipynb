# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# # Part 1: For Categorical Data

# %%
data = pd.read_csv("Dataset/play_tennis.csv")
data.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
# Calculating Initial Entropy
total = data.shape[0] # Total Number Of Columns
play_yes = data["play"].value_counts()[0]
play_no = data["play"].value_counts()[1]
p_play_yes = play_yes / total
p_play_no = play_no / total

print("Probability Of Playing =", p_play_yes)
print("Probability Of Not Playing =", p_play_no)
# Out:
# Probability Of Playing = 0.6428571428571429
# Probability Of Not Playing = 0.35714285714285715

# %%
# Initial Entropy
E_0 = -(p_play_yes * math.log(p_play_yes)) - (p_play_yes * math.log(p_play_no))
print("Initial Entropy =", E_0)
# Out:
# Initial Entropy = 0.9459335375101269

# %%
columns_used = data.columns[1:5]
for i in columns_used:
    data_group = data.groupby(i) # Forming Groups For Each Columns
    
    E_column = 0 # To Store Final Entropy For The Group
    
    for j in data_group.groups.keys():
        
        data_x = data_group.get_group(j)["play"] # Getting Play Column For the Specific Group
        
        total_values = data_x.shape[0] # Number Of Rows In That Group
        
        data_x = data_x.value_counts() # Number Of Yes or No
        
        # For The Play = Yes
        count_yes = data_x[0]
        p_count_yes = count_yes / total_values # Probability Of Playing
        e_yes = math.log(p_count_yes) # Entropy For Yes
        
        # For The Play = No 
        try:
            count_no = data_x[1]
            p_count_no = count_no / total_values # Probability Of Not Playing
            e_no = math.log(p_count_no) # Entropy For No
        except:
            p_count_no = 0 # If no "no" column is found.
            e_no = 0 
        
        E_group = -(p_count_yes*e_yes) - (p_count_no*e_no) # Entropy For The Group
        E_column = E_column + ((total_values/total)*E_group) # Weighted Entropy Calculation For Each Group
        
    print("Column =", i)
    print("Weighted Entropy =", E_column)
    print("Information Gain =", E_0 - E_column)
    print()
# Out:
# Column = outlook
# Weighted Entropy = 0.48072261929232607
# Information Gain = 0.4652109182178008
#
# Column = temp
# Weighted Entropy = 0.6315010221774208
# Information Gain = 0.3144325153327061
#
# Column = humidity
# Weighted Entropy = 0.5465122114944403
# Information Gain = 0.3994213260156866
#
# Column = wind
# Weighted Entropy = 0.6183974457364384
# Information Gain = 0.3275360917736885

# %%
data[data["outlook"] == "Overcast"]
# Out:
#     day   outlook  temp humidity    wind play
# 2    D3  Overcast   Hot     High    Weak  Yes
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes

# %% [markdown]
# ## Conclusion:
# Since, Outlook (Overcast) column has the highest information gain, we select that column as the initial node.

# %% [markdown]
# # Part 2: For Numerical Column

# %%
data = pd.read_csv("Dataset/Iris.csv")
data.sort_values("PetalLengthCm", inplace=True)
data.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 35  36            5.0           3.2            1.2           0.2  Iris-setosa
# 36  37            5.5           3.5            1.3           0.2  Iris-setosa

# %%
def entropy(group):
    data = group.groupby("Species").count()["Id"] # Getting Number Of Occurence Of Each Species
    total = data.sum() # Total Number Of Rows
    entropy_sum = 0 # To store entropy
    for i in data :
        p = i/total
        entropy_sum = entropy_sum - (p*math.log(p))
    return(entropy_sum) # Entropy For the group

# %%
total = data.shape[0]
p_setosa = 50/total
p_versicolor = 50/total
p_verginica = 50/total

E_0 = -(p_setosa * math.log(p_setosa))-(p_versicolor * math.log(p_versicolor))-(p_verginica * math.log(p_verginica))
print("Initial Entropy =", E_0)
# Out:
# Initial Entropy = 1.0986122886681096

# %%
max_value = -1 # To Store Maximum Entropy
point = -1 # To Store Break Point

# %%
for i in data["PetalLengthCm"].unique():
    
    group_1 = data[(data["PetalLengthCm"] > i)]
    group_2 = data[~(data["PetalLengthCm"] > i)]
    
    len_group_1 = group_1.shape[0]
    len_group_2 = group_2.shape[0]
    
    E_1 = entropy(group_1)
    E_2 = entropy(group_2)
    
    w_average = (len_group_1/total * E_1) + (len_group_2/total * E_2)
    IG = E_0 - w_average
    
    print("Breaking Point =", i)
    print("Weighted Entropy =", w_average)
    print("Information Gain=", IG)
    print()
    
    # For Getting The Maximum Breakpoint
    if(IG > max_value):
        max_value = IG
        point = i
# Out:
# Breaking Point = 1.0
# Weighted Entropy = 1.0912433629042542
# Information Gain= 0.007368925763855394
#
# Breaking Point = 1.1
# Weighted Entropy = 1.083783116337971
# Information Gain= 0.014829172330138585
#
# Breaking Point = 1.2
# Weighted Entropy = 1.0685784132540277
# Information Gain= 0.030033875414081868
#
# Breaking Point = 1.3
# Weighted Entropy = 1.012071146421969
# Information Gain= 0.08654114224614062
#
# Breaking Point = 1.4
# Weighted Entropy = 0.9001457603687307
# Information Gain= 0.19846652829937883
#
# Breaking Point = 1.5
# Weighted Entropy = 0.7309878754978658
# Information Gain= 0.36762441317024375
#
# Breaking Point = 1.6
# Weighted Entropy = 0.6158112441179745
# Information Gain= 0.48280104455013506
#
# Breaking Point = 1.7
# Weighted Entropy = 0.5277242136737411
# Information Gain= 0.5708880749943684
#
# Breaking Point = 1.9
# Weighted Entropy = 0.46209812037329684
# Information Gain= 0.6365141682948128
#
# Breaking Point = 3.0
# Weighted Entropy = 0.4902565152135314
# Information Gain= 0.6083557734545781
#
# Breaking Point = 3.3
# Weighted Entropy = 0.524782410959326
# Information Gain= 0.5738298777087836
#
# Breaking Point = 3.5
# Weighted Entropy = 0.5498155183012519
# Information Gain= 0.5487967703668577
#
# Breaking Point = 3.6
# Weighted Entropy = 0.5602146864264154
# Information Gain= 0.5383976022416942
#
# Breaking Point = 3.7
# Weighted Entropy = 0.5695359904586478
# Information Gain= 0.5290762982094618
#
# Breaking Point = 3.8
# Weighted Entropy = 0.5779352457069952
# Information Gain= 0.5206770429611144
#
# Breaking Point = 3.9
# Weighted Entropy = 0.5986259325205303
# Information Gain= 0.49998635614757925
#
# Breaking Point = 4.0
# Weighted Entropy = 0.6216389742732124
# Information Gain= 0.4769733143948972
#
# Breaking Point = 4.1
# Weighted Entropy = 0.6300232390644129
# Information Gain= 0.46858904960369663
#
# Breaking Point = 4.2
# Weighted Entropy = 0.6358019586350951
# Information Gain= 0.4628103300330144
#
# Breaking Point = 4.3
# Weighted Entropy = 0.6365141682948128
# Information Gain= 0.4620981203732968
#
# Breaking Point = 4.4
# Weighted Entropy = 0.6336520054014256
# Information Gain= 0.4649602832666839
#
# Breaking Point = 4.5
# Weighted Entropy = 0.6486510987183584
# Information Gain= 0.4499611899497512
#
# Breaking Point = 4.6
# Weighted Entropy = 0.6339163132292239
# Information Gain= 0.46469597543888563
#
# Breaking Point = 4.7
# Weighted Entropy = 0.5964425620215831
# Information Gain= 0.5021697266465265
#
# Breaking Point = 4.8
# Weighted Entropy = 0.6261557755433513
# Information Gain= 0.4724565131247582
#
# Breaking Point = 4.9
# Weighted Entropy = 0.6604944259021556
# Information Gain= 0.438117862765954
#
# Breaking Point = 5.0
# Weighted Entropy = 0.6954698379172438
# Information Gain= 0.40314245075086574
#
# Breaking Point = 5.1
# Weighted Entropy = 0.7723516137979146
# Information Gain= 0.32626067487019494
#
# Breaking Point = 5.2
# Weighted Entropy = 0.7980786233466858
# Information Gain= 0.3005336653214238
#
# Breaking Point = 5.3
# Weighted Entropy = 0.8225470874663406
# Information Gain= 0.2760652012017689
#
# Breaking Point = 5.4
# Weighted Entropy = 0.845902219605065
# Information Gain= 0.2527100690630446
#
# Breaking Point = 5.5
# Weighted Entropy = 0.8791001399884535
# Information Gain= 0.21951214867965607
#
# Breaking Point = 5.6
# Weighted Entropy = 0.9399663030499781
# Information Gain= 0.15864598561813148
#
# Breaking Point = 5.7
# Weighted Entropy = 0.9680798320910536
# Information Gain= 0.13053245657705592
#
# Breaking Point = 5.8
# Weighted Entropy = 0.9948741568520147
# Information Gain= 0.10373813181609481
#
# Breaking Point = 5.9
# Weighted Entropy = 1.012071146421969
# Information Gain= 0.08654114224614062
#
# Breaking Point = 6.0
# Weighted Entropy = 1.0287759284375364
# Information Gain= 0.06983636023057316
#
# Breaking Point = 6.1
# Weighted Entropy = 1.0529764713581733
# Information Gain= 0.045635817309936266
#
# Breaking Point = 6.3
# Weighted Entropy = 1.0608285337900285
# Information Gain= 0.037783754878081055
#
# Breaking Point = 6.4
# Weighted Entropy = 1.0685784132540277
# Information Gain= 0.030033875414081868
#
# Breaking Point = 6.6
# Weighted Entropy = 1.0762290162219126
# Information Gain= 0.022383272446196978
#
# Breaking Point = 6.7
# Weighted Entropy = 1.0912433629042542
# Information Gain= 0.007368925763855394
#
# Breaking Point = 6.9
# Weighted Entropy = 1.0986122886681096
# Information Gain= 0.0

# %%
print("Point Where Maximum Information Gain Occurs =", point)
# Out:
# Point Where Maximum Information Gain Occurs = 1.9

# %%
for i in data[data["PetalLengthCm"] < 1.9]["Species"].tolist():
    print(i)
# Out:
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa
# Iris-setosa

# %% [markdown]
# ## Conclusion:
# Iris-Setosa Can easily be distincted from this breakpoint.
